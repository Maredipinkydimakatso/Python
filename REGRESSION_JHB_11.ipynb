# %% [markdown]
# <a href="https://colab.research.google.com/github/Maredipinkydimakatso/Python/blob/master/REGRESSION_JHB_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the dataset

# %% [markdown]
# # Train Data

# %%
mytrain = pd.read_csv('Train.csv')

# %%
mytrain.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
mytrain.tail()
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 21196             Personal                        20
# 21197             Business                        13
# 21198             Business                         7
# 21199             Personal                         4
# 21200             Business                        26
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 21196                             3       3:54:38 PM
# 21197                             6      10:13:34 AM
# 21198                             4       5:06:16 PM
# ...

# %% [markdown]
# # Riders

# %%
myrider = pd.read_csv('Riders.csv')

# %%
myrider.head()
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156

# %%
train_df= pd.merge(mytrain,myrider,on="Rider Id")

# %%
train_df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1   Order_No_2699   User_Id_592         Bike              1
# 2  Order_No_21486   User_Id_478         Bike              3
# 3  Order_No_19336  User_Id_2801         Bike              3
# 4  Order_No_20374  User_Id_3465         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Personal                        26
# 2             Business                        29
# 3             Business                         2
# 4             Business                        14
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             2       2:43:21 PM                           26
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7068 entries, 0 to 7067
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Order No                              7068 non-null   object
#  1   User Id                               7068 non-null   object
#  2   Vehicle Type                          7068 non-null   object
#  3   Platform Type                         7068 non-null   int64
#  4   Personal or Business                  7068 non-null   object
#  5   Placement - Day of Month              7068 non-null   int64
#  6   Placement - Weekday (Mo = 1)          7068 non-null   int64
#  7   Placement - Time                      7068 non-null   object
#  8   Confirmation - Day of Month           7068 non-null   int64
#  9   Confirmation - Weekday (Mo = 1)       7068 non-null   int64
#  10  Confirmation - Time                   7068 non-null   object
# ...

# %%
train_df.shape
# Out:
# (7068, 28)

# %% [markdown]
# # Data engineering

# %%
train_df.columns=[col.replace(' ','_') for col in train_df.columns]
train_df.head()
# Out:
#          Order_No       User_Id Vehicle_Type  Platform_Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1   Order_No_2699   User_Id_592         Bike              1
# 2  Order_No_21486   User_Id_478         Bike              3
# 3  Order_No_19336  User_Id_2801         Bike              3
# 4  Order_No_20374  User_Id_3465         Bike              3
#
#   Personal_or_Business  Placement_-_Day_of_Month  \
# 0             Business                        27
# 1             Personal                        26
# 2             Business                        29
# 3             Business                         2
# 4             Business                        14
#
#    Placement_-_Weekday_(Mo_=_1) Placement_-_Time  Confirmation_-_Day_of_Month  \
# 0                             3       4:44:10 PM                           27
# 1                             2       2:43:21 PM                           26
# ...

# %%
#Dropping the 'Precipitation_in_millimeters' column since it has very few valid entries
# 199 non-null entries out of 7068
train_df=train_df.drop(['Precipitation_in_millimeters'], axis=1)
train_df.head()
# Out:
#          Order_No       User_Id Vehicle_Type  Platform_Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1   Order_No_2699   User_Id_592         Bike              1
# 2  Order_No_21486   User_Id_478         Bike              3
# 3  Order_No_19336  User_Id_2801         Bike              3
# 4  Order_No_20374  User_Id_3465         Bike              3
#
#   Personal_or_Business  Placement_-_Day_of_Month  \
# 0             Business                        27
# 1             Personal                        26
# 2             Business                        29
# 3             Business                         2
# 4             Business                        14
#
#    Placement_-_Weekday_(Mo_=_1) Placement_-_Time  Confirmation_-_Day_of_Month  \
# 0                             3       4:44:10 PM                           27
# 1                             2       2:43:21 PM                           26
# ...

# %%
train_df.columns
# Out:
# Index(['Order_No', 'User_Id', 'Vehicle_Type', 'Platform_Type',
#        'Personal_or_Business', 'Placement_-_Day_of_Month',
#        'Placement_-_Weekday_(Mo_=_1)', 'Placement_-_Time',
#        'Confirmation_-_Day_of_Month', 'Confirmation_-_Weekday_(Mo_=_1)',
#        'Confirmation_-_Time', 'Arrival_at_Pickup_-_Day_of_Month',
#        'Arrival_at_Pickup_-_Weekday_(Mo_=_1)', 'Arrival_at_Pickup_-_Time',
#        'Pickup_-_Day_of_Month', 'Pickup_-_Weekday_(Mo_=_1)', 'Pickup_-_Time',
#        'Distance_(KM)', 'Temperature', 'Pickup_Lat', 'Pickup_Long',
#        'Destination_Lat', 'Destination_Long', 'Rider_Id', 'No_Of_Orders',
#        'Age', 'Average_Rating', 'No_of_Ratings'],
#       dtype='object')

# %%
X = train_df.iloc[:, 18:-9].head()

# %%
print (X)
# Out:
#    Temperature
# 0          NaN
# 1          NaN
# 2         19.7
# 3         16.4
# 4         21.3

# %%
#The temperature column has NaN values and so must be filled 
#In this case the average of tempetures was used 
train_df['Temperature'].fillna(train_df['Temperature'].mean(), inplace=True)

# %%
train_df.head()
# Out:
#          Order_No       User_Id Vehicle_Type  Platform_Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1   Order_No_2699   User_Id_592         Bike              1
# 2  Order_No_21486   User_Id_478         Bike              3
# 3  Order_No_19336  User_Id_2801         Bike              3
# 4  Order_No_20374  User_Id_3465         Bike              3
#
#   Personal_or_Business  Placement_-_Day_of_Month  \
# 0             Business                        27
# 1             Personal                        26
# 2             Business                        29
# 3             Business                         2
# 4             Business                        14
#
#    Placement_-_Weekday_(Mo_=_1) Placement_-_Time  Confirmation_-_Day_of_Month  \
# 0                             3       4:44:10 PM                           27
# 1                             2       2:43:21 PM                           26
# ...
